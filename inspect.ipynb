# %%
import xarray as xr

# %%
xr.open_dataset("forecast_netcdfs_powercurve_obs/GraphTransformer_PowerCurve_Belwind_Phase_1.nc")['truth'].isel(date=10).values
# Out:
# array([  6.       ,   2.6666667,   2.       ,   6.6666665,  33.       ,
#         55.       ,  36.333332 ,  49.333332 ,  48.333332 ,  97.666664 ,
#        161.       , 160.66667  , 158.66667  , 133.       ,  81.333336 ,
#         51.666668 ,  33.333332 ,  54.333332 , 114.333336 , 127.333336 ,
#        131.33333  , 122.666664 , 113.666664 ,  88.       ,  54.333332 ],
#       dtype=float32)

# %%
xr.open_dataset("forecast_netcdfs/GraphTransformer_dim128_heads4_layers4_Belwind_Phase_1.nc")
# Out:
# <xarray.Dataset> Size: 102kB
# Dimensions:    (date: 488, lead_time: 25)
# Coordinates:
#   * date       (date) datetime64[ns] 4kB 2025-06-01 ... 2025-07-31T21:00:00
#   * lead_time  (lead_time) int32 100B 0 1 2 3 4 5 6 7 ... 18 19 20 21 22 23 24
# Data variables:
#     forecast   (date, lead_time) float32 49kB ...
#     truth      (date, lead_time) float32 49kB ...
